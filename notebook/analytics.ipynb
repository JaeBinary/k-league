# %%
import pandas as pd
import sqlite3

DB_PATH = "..\\data\\kleague.db"

# %%
# Context Manager 사용 (권장)
with sqlite3.connect(DB_PATH) as conn:
    query = f"""
            SELECT *
            FROM match
            """
    result = pd.read_sql(query, conn)
display(result.dtypes.to_frame(name='dtype'))
# Out:
#                  dtype
# Meet_Year        int64
# LEAGUE_NAME     object
# Round            int64
# Game_id          int64
# Game_Datetime   object
# Day             object
# HomeTeam        object
# AwayTeam        object
# HomeRank         int64
# AwayRank         int64
# Field_Name      object
# Audience_Qty     int64
# Weather         object
# Temperature    float64
# Humidity         int64

# %%
# Context Manager 사용 (권장)
with sqlite3.connect(DB_PATH) as conn:
    query = f"""
            SELECT
                *
            FROM match
            """
    result = pd.read_sql(query, conn)
result
# Out:
#       Meet_Year LEAGUE_NAME  Round  Game_id        Game_Datetime Day HomeTeam  \
# 0          2023        K리그1      1        1  2023-02-25 14:00:00   토       울산
# 1          2023        K리그1      1        2  2023-02-25 16:30:00   토       서울
# 2          2023        K리그1      1        3  2023-02-25 16:30:00   토       수원
# 3          2023        K리그1      1        4  2023-02-26 14:30:00   일       포항
# 4          2023        K리그1      1        5  2023-02-26 14:00:00   일       제주
# ...         ...         ...    ...      ...                  ...  ..      ...
# 1426       2025        K리그2     39      271  2025-11-23 14:00:00   일      서울E
# 1427       2025        K리그2     39      272  2025-11-23 14:00:00   일       경남
# 1428       2025        K리그2     39      273  2025-11-23 14:00:00   일       성남
# 1429       2025        K리그2     40      274  2025-11-27 19:00:00   목      서울E
# 1430       2025        K리그2     41      275  2025-11-30 14:00:00   일       부천
#
#      AwayTeam  HomeRank  AwayRank   Field_Name  Audience_Qty Weather  \
# 0          전북         0         0  울산 문수 축구경기장         28039      맑음
# 1          인천         0         0   서울 월드컵 경기장         22204      맑음
# 2          광주         0         0   수원 월드컵 경기장         10348      맑음
# 3          대구         0         0      포항 스틸야드         14089      맑음
# 4        수원FC         0         0   제주 월드컵 경기장          8362      맑음
# ...       ...       ...       ...          ...           ...     ...
# 1426       안산         5        14    목동 종합 운동장          5211      흐림
# 1427       천안        11        12      창원 축구센터          3007      맑음
# 1428       부산         6         7    탄천 종합 운동장          3703      맑음
# 1429       성남         4         5    목동 종합 운동장          4147      흐림
# 1430       성남         3         5    부천 종합 운동장          6171      흐림
#
#       Temperature  Humidity
# 0             7.0        33
# 1             4.7        25
# 2             4.9        28
# 3            10.0         0
# 4             8.0        44
# ...           ...       ...
# 1426         15.0        55
# 1427         14.5        45
# 1428         11.4        62
# 1429          7.5        62
# 1430         15.0        75
#
# [1431 rows x 15 columns]
